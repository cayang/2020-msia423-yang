# %%
# %load_ext nb_black

# %%
import sys
import pathlib

HOME = str(pathlib.Path(sys.path[0]).parents[1])
sys.path.append(HOME + "/src")
sys.path.append(HOME + "/data/raw")
sys.path.append(HOME + "/data/processed")

# %%
# Imports
import pandas as pd
import numpy as np
import datetime
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import seaborn as sns

# From files
from data_import_and_cleaning import get_cleaned_data

# %%
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 110)

# %%
# Constants
pull_date = datetime.datetime(2019, 11, 21)

# %% [markdown]
# # Read in Data

# %%
# Define filepaths
data_path = pathlib.Path(HOME) / "data" / "raw"
data_path_listings = data_path / "chicago_listings-20191121.csv"

# %%
# Read in and process data
df_listings = get_cleaned_data(data_path_listings)

# %%
# Preview dataframe
df_listings.head(5)
# Out:
#       id                                               name  \
# 0   2384  Walk to UChicago, 10 min train to McCormick Place
# 1   4505  One Great Apartment. 384 Great Reviews. 1 Bad ...
# 2   7126                Tiny Studio Apartment 94 Walk Score
# 3   9811                      Barbara's Hideaway - Old Town
# 4  10610                   3 Comforts of Cooperative Living
#
#                                              summary  \
# 0  Visiting The University of Chicago or attendin...
# 1  We took the winter off, made things nicer arou...
# 2   A very small studio in a wonderful neighborhood.
# 3  One-bedroom hideaway tucked into Old Town step...
# 4  The condo is the 2nd floor in a lovely 1912 3-...
#
#                                                space  \
# 0  The private bedroom has a queen size bed, beds...
# 1  We travel a lot, we know what people need.  We...
# 2  This is a very small  studio apartment with a ...
# 3  This lovely one bedroom "hideaway" is located ...
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data Checking

# %%
# Dataset size
df_listings.shape
# Out:
# (8533, 86)

# %%
# Check NAs for each column
df_listings.isna().sum()
# Out:
# id                                                 0
# name                                               0
# summary                                          234
# space                                           1543
# description                                      129
# neighborhood_overview                           2051
# notes                                           3651
# transit                                         2313
# access                                          2944
# interaction                                     2476
# house_rules                                     2287
# host_id                                            0
# host_name                                          0
# host_since                                         0
# host_location                                     11
# host_about                                      2675
# host_response_time                               824
# host_response_rate                               824
# ...
